# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("DataCoSupplyChainDataset.csv",encoding = 'latin-1')
df.head()
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0          91.250000          314.640015  Advance shipping
# 1        -249.089996          311.359985     Late delivery
# 2        -247.779999          309.720001  Shipping on time
# 3          22.860001          304.809998  Advance shipping
# 4         134.210007          298.250000  Advance shipping
#
#    Late_delivery_risk  Category Id   Category Name Customer City  ...  \
# 0                   0           73  Sporting Goods        Caguas  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99998 entries, 0 to 99997
# Data columns (total 53 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Type                           99998 non-null  object
#  1   Days for shipping (real)       99998 non-null  int64
#  2   Days for shipment (scheduled)  99998 non-null  int64
#  3   Benefit per order              99998 non-null  float64
#  4   Sales per customer             99998 non-null  float64
#  5   Delivery Status                99998 non-null  object
#  6   Late_delivery_risk             99998 non-null  int64
#  7   Category Id                    99998 non-null  int64
#  8   Category Name                  99998 non-null  object
#  9   Customer City                  99998 non-null  object
#  10  Customer Country               99998 non-null  object
#  11  Customer Email                 99998 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Type                                 0
# Days for shipping (real)             0
# Days for shipment (scheduled)        0
# Benefit per order                    0
# Sales per customer                   0
# Delivery Status                      0
# Late_delivery_risk                   0
# Category Id                          0
# Category Name                        0
# Customer City                        0
# Customer Country                     0
# Customer Email                       0
# Customer Fname                       0
# Customer Id                          0
# Customer Lname                       5
# Customer Password                    0
# Customer Segment                     0
# Customer State                       0
# Customer Street                      0
# Customer Zipcode                     3
# Department Id                        0
# Department Name                      0
# Latitude                             0
# Longitude                            0
# ...

# %%
df_base = df[['Order Item Total', 'Shipping Mode']]
